# %% [markdown]
# ## Part 1

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ### Loading the Data

# %%
import pandas as pd

reaction_df = pd.read_csv("Reactions.csv", na_values=[""])
content_df = pd.read_csv("Content.csv")
reaction_types_df = pd.read_csv("ReactionTypes.csv")

# %%
content_df
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
reaction_df
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
reaction_types_df
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %% [markdown]
# ### Check the data

# %%
reaction_df.isna().sum()
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
content_df.isna().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %% [markdown]
# ### Cleaning the content data

# %%
content_df['Category'] = content_df['Category'].str.replace('"', '')

# %% [markdown]
# ### Remove User ID and URL columns as they not necessary

# %%
content_df.drop(columns=['User ID'], inplace=True)

# %%
content_df.drop(columns=['URL'], inplace=True)

# %%
content_df
# Out:
#      Unnamed: 0                            Content ID   Type         Category
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2  photo         Studying
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo   healthy eating
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f  photo   healthy eating
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6  photo       technology
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180  video             food
# ..          ...                                   ...    ...              ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb  video  public speaking
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c    GIF       technology
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b  audio         veganism
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    GIF          culture
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56  audio       technology
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Renaming Column "Type" to "Content Type" Just to be specific

# %%
content_df.rename(columns={'Type': 'Content Type'}, inplace=True)

# %%
content_df
# Out:
#      Unnamed: 0                            Content ID Content Type  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6        photo
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180        video
# ..          ...                                   ...          ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb        video
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c          GIF
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b        audio
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56        audio
#
#             Category
# 0           Studying
# 1     healthy eating
# 2     healthy eating
# 3         technology
# 4               food
# ..               ...
# ...

# %% [markdown]
# ### Cleaning Reactions.csv

# %%
# Remove Rows with Blanks

reaction_df.dropna(inplace=True)

# %%
# Remove "User ID" Column

reaction_df.drop(columns=['User ID'], inplace=True)

# %%
# Renaming Type to Reaction Type

reaction_df.rename(columns={'Type': 'Reaction Type'}, inplace=True)

# %%
reaction_df
# Out:
#        Unnamed: 0                            Content ID Reaction Type  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...           ...                                   ...           ...
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime
# 1      2020-11-07 09:43:50
# 2      2021-06-17 12:22:51
# 3      2021-04-18 05:13:58
# ...

# %%
# Renaming Type to Reaction Type in reation_types_df

reaction_types_df.rename(columns={'Type': 'Reaction Type'}, inplace=True)

# %%
reaction_types_df
# Out:
#     Unnamed: 0 Reaction Type Sentiment  Score
# 0            0         heart  positive     60
# 1            1          want  positive     70
# 2            2       disgust  negative      0
# 3            3          hate  negative      5
# 4            4    interested  positive     30
# 5            5   indifferent   neutral     20
# 6            6          love  positive     65
# 7            7    super love  positive     75
# 8            8       cherish  positive     70
# 9            9         adore  positive     72
# 10          10          like  positive     50
# 11          11       dislike  negative     10
# 12          12     intrigued  positive     45
# 13          13       peeking   neutral     35
# 14          14        scared  negative     15
# 15          15       worried  negative     12

# %% [markdown]
# ## Part 2

# %% [markdown]
# ### 1. Merging the Data Sets

# %%
# Merge Reactions with Content
merged_df = reaction_df.merge(content_df, on='Content ID', how='left')

# Merge the result with Reaction Types
final_df = merged_df.merge(reaction_types_df, on='Reaction Type', how='left')

# %%
final_df
# Out:
#        Unnamed: 0_x                            Content ID Reaction Type  \
# 0                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1                 2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2                 3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4                 5  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...             ...                                   ...           ...
# 22529         25547  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 22530         25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 22531         25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 22532         25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 22533         25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime  Unnamed: 0_y Content Type    Category  Unnamed: 0  \
# ...

# %% [markdown]
# ### 2. Calculating the Total Scores for Each Category

# %%
# Calculate total scores by category
category_scores = final_df.groupby('Category')['Score'].sum().reset_index()

# Sort categories by total score in descending order
top_categories = category_scores.sort_values(by='Score', ascending=False)

# Display the top 5 categories
top_5_categories = top_categories.head(5)
print(top_5_categories)
# Out:
#           Category  Score
# 13         animals  65063
# 20  healthy eating  62866
# 25      technology  62818
# 22         science  61081
# 15         culture  59213

# %% [markdown]
# ### 3. Saving the Final Data Set

# %%
final_df.to_csv("Final_Cleaned_Data.csv", index=False)
top_5_categories.to_csv("Top_5_Categories.csv", index=False)

# %% [markdown]
# ## Plotting the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: Set a style for the plots
sns.set_style("whitegrid")

# %%
# Plot top 5 categories
plt.figure(figsize=(10, 6))
sns.barplot(data=top_5_categories, x='Category', y='Score', palette='viridis')
plt.title('Top 5 Content Categories by Total Score', fontsize=16)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Total Score', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Distribution plot for scores
plt.figure(figsize=(8, 5))
sns.histplot(final_df['Score'], bins=30, kde=True, color='blue')
plt.title('Distribution of Reaction Scores', fontsize=16)
plt.xlabel('Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.tight_layout()
plt.show()

# %%
reaction_type_scores = final_df.groupby('Reaction Type')['Score'].sum().reset_index()

# Pie chart for reaction type scores
plt.figure(figsize=(8, 8))
plt.pie(reaction_type_scores['Score'], labels=reaction_type_scores['Reaction Type'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('coolwarm', len(reaction_type_scores)))
plt.title('Reaction Types by Total Score', fontsize=16)
plt.axis('equal')  # Equal aspect ratio ensures a circular pie chart
plt.show()
